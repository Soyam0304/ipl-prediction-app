# %%
import pandas as pd

# %%
dataset1=pd.read_csv("deliveries.csv")
dataset=pd.read_csv("matches.csv")
dataset1
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
total_score=dataset1.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
total_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
total_score = total_score[total_score['inning']==1]

# %%
total_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
match=dataset.merge(total_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
 match['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = ['Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bangalore',
       'Kolkata Knight Riders','Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals', 
       'Delhi Capitals']

# %%
match['team1']=match['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match['team2']=match['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match['team1']=match['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match['team2']=match['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match = match[match['team1'].isin(teams)]
match = match[match['team2'].isin(teams)]

# %%
match.head(2)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#        umpire1   umpire2 umpire3  match_id  total_runs
# ...

# %%
match.shape
# Out:
# (641, 20)

# %%
#we are removing matches where duck wearth lewis is available 
# 1 = yes , 0 = no
match=match[match['dl_applied']==0]

# %%
match.shape
# Out:
# (626, 20)

# %%
match=match[['match_id','city','winner','total_runs']]

# %%
final=match.merge(dataset1,on='match_id')

# %%
final.head()
# Out:
#    match_id       city               winner  total_runs_x  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad           207       1
# 1         1  Hyderabad  Sunrisers Hyderabad           207       1
# 2         1  Hyderabad  Sunrisers Hyderabad           207       1
# 3         1  Hyderabad  Sunrisers Hyderabad           207       1
# 4         1  Hyderabad  Sunrisers Hyderabad           207       1
#
#           batting_team                 bowling_team  over  ball    batsman  \
# 0  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner
# 1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner
# 2  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3  DA Warner
# 3  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4  DA Warner
# 4  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5  DA Warner
#
#    ... bye_runs legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
final = final[final['inning'] == 2]

# %%
final.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %%
final.shape
# Out:
# (72413, 24)

# %%
final.head(2)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# 126  Mandeep Singh  ...        0           0            0             0
#
#      batsman_runs  extra_runs  total_runs_y  player_dismissed  dismissal_kind  \
# 125             1           0             1               NaN             NaN
# 126             0           0             0               NaN             NaN
#
#      fielder
# 125      NaN
# 126      NaN
#
# [2 rows x 24 columns]

# %%
final['total_runs_y']
# Out:
# 125       1
# 126       0
# 127       0
# 128       2
# 129       4
#          ..
# 149573    1
# 149574    2
# 149575    1
# 149576    2
# 149577    0
# Name: total_runs_y, Length: 72413, dtype: int64

# %%
final['total_runs_y'] = final['total_runs_y'].astype('int64')

# %%
final['total_runs_y']
# Out:
# 125       1
# 126       0
# 127       0
# 128       2
# 129       4
#          ..
# 149573    1
# 149574    2
# 149575    1
# 149576    2
# 149577    0
# Name: total_runs_y, Length: 72413, dtype: int64

# %%
final['current_score']=final.groupby('match_id')['total_runs_y'].cumsum()

# %%
final['runs_left'] = final['total_runs_x']-final['current_score']

# %%
final['balls left'] = 120 - (final['over']*6 + final['ball'])

# %%
final.head(2)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# 126  Mandeep Singh  ...            0            0           0             0
#
#      player_dismissed  dismissal_kind  fielder  current_score  runs_left  \
# 125               NaN             NaN      NaN              1        206
# 126               NaN             NaN      NaN              1        206
#
#      balls left
# 125         113
# 126         112
#
# [2 rows x 27 columns]

# %%
final['player_dismissed']=final["player_dismissed"].fillna(0)

# %%
final.head(3)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# 126  Mandeep Singh  ...            0            0           0             0
# 127  Mandeep Singh  ...            0            0           0             0
#
#      player_dismissed  dismissal_kind  fielder  current_score  runs_left  \
# ...

# %%
final['player_dismissed']=final['player_dismissed'].apply(lambda x : x if x == 0 else 1 )
final['player_dismissed'] = final['player_dismissed'].astype('int64')

# %%
wickets = final.groupby('match_id')['player_dismissed'].cumsum().values
final['wicket'] = 10 - wickets

# %%
final.head(3)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# 126  Mandeep Singh  ...            0          0             0
# 127  Mandeep Singh  ...            0          0             0
#
#      player_dismissed  dismissal_kind  fielder  current_score  runs_left  \
# 125                 0             NaN      NaN              1        206
# ...

# %%
final.tail()
# Out:
#         match_id       city          winner  total_runs_x  inning  \
# 149573     11415  Hyderabad  Mumbai Indians           152       2
# 149574     11415  Hyderabad  Mumbai Indians           152       2
# 149575     11415  Hyderabad  Mumbai Indians           152       2
# 149576     11415  Hyderabad  Mumbai Indians           152       2
# 149577     11415  Hyderabad  Mumbai Indians           152       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        batsman_runs extra_runs  total_runs_y  player_dismissed  \
# 149573            1          0             1                 0
# ...

# %%
# current run rate = runs/overs
final['crr']=(final['current_score']*6)/(120 - final['balls left'])

# %%
#rrr 
final['rrr'] = (final['runs_left']*6)/final['balls left']

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
final['result']=final.apply(result,axis=1)

# %%
final1 =final[['batting_team','bowling_team','city','runs_left','balls left','wicket','total_runs_x','crr','rrr','result']]

# %%
final1
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls left  wicket  total_runs_x       crr        rrr  \
# 125           206         113      10           207  0.857143  10.938053
# ...

# %%
skdjfhklas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 skdjfhklas
#
# NameError: name 'skdjfhklas' is not defined

# %%
final1=final1.sample(final.shape[0])

# %%
final1.dropna(inplace=True)

# %%
final1.head(3)

# %%
final1 = final1[final1['balls left']!=0]

# %%
x = final1.iloc[:,:-1]
y = final1.iloc[:,-1]

# %%
final1['city'].unique()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer(
    [('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])],
    remainder='passthrough'
)

# %%
help(ColumnTransformer)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[('step1',trf),('step2',LogisticRegression(solver='liblinear'))])

# %%
pipe.fit(x_train,y_train)
pipe.score(x_train,y_train)*100 , pipe.score(x_test,y_test)*100

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
import numpy as np
accuracy_score(y_test,y_pred)*100

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB,GaussianNB
from sklearn.svm import SVC

# %%
dt = DecisionTreeClassifier()
mu = MultinomialNB()
be = BernoulliNB()
ga = GaussianNB()
sv = SVC()

# %%
pipe2 = Pipeline(steps=[('step1',trf),('step2',DecisionTreeClassifier())])
pipe3 = Pipeline(steps=[('step1',trf),('step2',MultinomialNB())])
pipe4 = Pipeline(steps=[('step1',trf),('step2',SVC())])

# %%
pipe2.fit(x_train,y_train)
pipe2.score(x_train,y_train)*100 , pipe2.score(x_test,y_test)*100

# %%
def get_user_input():
    batting_team = input("Enter the batting team: ")
    bowling_team = input("Enter the bowling team: ")
    city = input("Enter the city: ")
    current_over = int(input("Enter the current over: "))
    
    overs_left = 20 - current_over 
    
    # Calculating derived inputs
    balls_left = overs_left * 6
    current_score = int(input("Enter the current score: "))
    target_score = int(input("Enter the target score: "))
    runs_left = target_score - current_score
    wic = int(input("Enter the number of wickets down: "))
    wickets_left = 10 - wic
    
    # Calculating crr and rrr
    crr = (current_score * 6) / (120 - balls_left)
    rrr = (runs_left * 6) / balls_left
    
    # Prepare the dataframe
    data = {
        'batting_team': [batting_team],
        'bowling_team': [bowling_team],
        'city': [city],
        'runs_left': [runs_left],
        'balls left': [balls_left],
        'wicket': [wickets_left],
        'total_runs_x': [target_score],
        'crr': [crr],
        'rrr': [rrr],
        'overs_left':[overs_left]
    }
    
    return pd.DataFrame(data)

def predict_match_outcome(pipe):
    
    new_match_df = get_user_input()
    
    # Predict probabilities using the trained pipeline
    result = pipe2.predict_proba(new_match_df)
    new_match_df['lose'] = np.round(result.T[0] * 100, 1)
    new_match_df['win'] = np.round(result.T[1] * 100, 1)
    #new = user
    #result = pipe.predict_prob(new)
    #new['loss'] = np.round(result.T[0] * 100,1)
    #new['win'] = np.round(result.T[1]*100,1)
    
   
    # Display the results
    print(new_match_df[['balls left','runs_left']])
    print(new_match_df[['overs_left','crr', 'rrr', 'win','lose']])
    
#predict_match_outcome(pipe)

# %%
teams = ['Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bangalore',
       'Kolkata Knight Riders','Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals', 
       'Delhi Capitals']

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
pipe4.fit(x_train,y_train)
pipe4.score(x_train,y_train)*100 , pipe4.score(x_test,y_test)*100

# %%
pipe5 = Pipeline(steps=[('step1',trf),('step2',BernoulliNB())])

# %%
pipe5.fit(x_train,y_train)
pipe5.score(x_train,y_train)*100 , pipe5.score(x_test,y_test)*100

# %%
pipe6 = Pipeline(steps=[('step1',trf),('step2',DecisionTreeClassifier(max_depth=7))])

# %%
pipe6.fit(x_train,y_train)
pipe6.score(x_train,y_train)*100 , pipe6.score(x_test,y_test)*100

# %%
predict_match_outcome(pipe6)
